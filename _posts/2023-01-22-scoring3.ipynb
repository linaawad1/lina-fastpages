# %% [markdown]
# # Performance Task Scoring 3
# > lina awad
#
# - toc: true
# - layout: base
# - badges: true
# - categories: [other]

# %% [markdown]
# ### Project 1
#
# |Category|CB Score|My Score|Why|
# |---|---|---|---|
# |Program Purpose and Function|1|0|I thought this written response lacks a clear program goal; instead, it is overly general and only describes functionality. Besides the written response, there was an obvious purpose and function within the actual program which is why I thought it may earn credit.|
# |Data Abstraction|0|0|Even though some of the requirements are met, the use of data abstraction doesn't directly impact the programs purpose/function. It may be defined, but it is not very program-specific.|
# |Managing Complexity|0|1|Due to the fact that it provided a reasonable depiction, I believed that it would manage complexity. But it isn't unique or specific. I t is wrong to claim that lists were useful and that the software could have been built differently if they hadn't been used.|
# |Procedural Abstraction|0|0|This shows the parameters of the code, but the procedure that the students develop is not clear enough to the user or reader.|
# |Algorithm Implementation|1|1|There are indications of sequencing, selection, and iteration in the program's code. The sample makes its entire argument because the details are also quite evident.|
# |Testing|1|1|The student explains the process that is being tested, how it should function, and why each component is important, assuming that testing goes as expected.|
#
# ### Reflection
# Discrepencies:
# - I had two overall discrepencies compared to the college board scorers. For one, I gave this submission a point for their purpose and function. I think that one thing you have to do as a grader is not assume anything and instead look for proof. If they don't clearly state program purpose and function I shouldn't create it for them. Also I gave them an unearned point for managing complexity. I should be on the lookout for submissions with lists that don't serve a specific purpose or are missing components.
#
# How my project can meet standards(How am I going to use these lessons?):
# - My project can meet these standards by listing everything I can possibly think of. From a student perspective instead of a grader perspective I need to not make the grader assume. Everything should be clearly listed. I also need to make sure that the lists and code I add are relevant to the purpose and function of the overall program.
#
#
# ### Project 2
#
# |Category|CB Score|My Score|Why|
# |---|---|---|---|
# |Program Purpose and Function|1|1|This recieved full credit for program purpose and function because the two ideas were very distinct and I could identify them both in seperate ways.|
# |Data Abstraction|1|1|The data abstraction portion earned 1 point because the list is used correctly and an active part of the program. The variable names are clear and the datas purpose is also very clear.|
# |Managing Complexity|1|1|This included the code segments that helped manage complexity. They also described how this code is essential and how it provides purpose to the program.|
# |Procedural Abstraction|1|1|The student showed the parameters of the code and their functions as well as explaining the procedure/purpose. It explains the procedures link to the rest of the program.|
# |Algorithm Implementation|1|1|The programs code has evidence of sequencing, selection, and iteration. The details are also super clear which gives the sample the full point.|
# |Testing|1|1|The student describes the procedure that is being checked and how it is supposed to run as well as the purpose of each aspect assuming it tests as planned.|
#
# ### Reflection
# Discrepencies:
# - There were not any differences or confusions with this example because all the pieces were clear to see and understand. I could point out each part and what criteria it met, so I gave everything full credit just like what it earned from college board.
#
# How my project can meet standards(How am I going to use these lessons?):
# - One thing I took away from this sample that I can use for my future work is how they explained their procedure and code with a lot of detail. It showed me a good example of how to explain in order to show full understanding. I also learned that explanations of each section will go very far so I will implement that when creating my program.
#
#
# ### Project 3
#
# |Category|CB Score|My Score|Why|
# |---|---|---|---|
# |Program Purpose and Function|1|1|The input, output, and program purpose + function are all well displayed/described in their written and video responses. The function and purpose are also distinct and separate so they each can be described. Therefore, it will earn full credti.|
# |Data Abstraction|0|0|Although some of the requirements are met, the use of data abstraction doesn't directly impact the programs purpose/function. It may be defined, but it is not very program-specific.|
# |Managing Complexity|0|0|he program that is used doesn't provide the necessary purpose of managing complexity. Despite describing and showing the lists purpose, it doesn't link to managing the full complexity of the program like it is being asked, so it gets no credit.|
# |Procedural Abstraction|0|0|This shows the parameters of the code, but the procedure that the students develop is not clear enough to the user or reader.|
# |Algorithm Implementation|0|0|Despite the student including the sequencing, selection, and iteration, they didn't detail the inner workings of the code enough. It must be able to be recreated and followed according to college board.|
# |Testing|0|1|I thought that the process being tested was clear, but in reality the student only describse the conditions tested and does not really describe the arguments of the code execution, earning it a 0|
#
# ### Reflection
# Discrepencies:
# - My one difference between my scoring and college board scoring was that I though this student earned the testing point in that category. I thought that it may earn a point for setting the conditions in relation to the parameters, but in reality there are insignificant aspects that don't earn the point.
#
# How my project can meet standards(How am I going to use these lessons?):
# - I can use what I learned from this submission in my project by listing clear parameters and conditions to be met. They must have the clear conditions and show the significance of each step. If parts of it don't line up or go with what the project was previously about, then the purpose and function is never really acheived and it does not show full understanding.
#
#
# ### Project 4
#
# |Category|CB Score|My Score|Why|
# |---|---|---|---|
# |Program Purpose and Function|1|1|Because the two concepts were so distinct and I could recognize them both separately, this received full credit for the program's goal and function. It was clear in the written response as well as video.|
# |Data Abstraction|1|1|The list is used correctly and is an active component of the program, earning the data abstraction section 1 point. The objective of the data is also extremely apparent, just like the variable names. It is clear and well done.|
# |Managing Complexity|1|1|This included the parts of the code that helped with complexity management. They also discussed the significance of this code and how it gives the program direction which is essential in the written response for the full point.|
# |Procedural Abstraction|1|1|The student explained the parameters and goal while also demonstrating the code's purpose and their functions. It explains how the various steps fit into the overall program and are useful parts in the project as a whole tying it together.|
# |Algorithm Implementation|1|1|There is indications of sequencing, selection, and iteration in the program's code. The sample makes its entire point because the details are also quite evident showing how each steps work.|
# |Testing|0|1|I also got a different score than college board on the testing portion for this submission because it mentions some conditions but it doesn't entirely match up with the parameters and only describes the code, not the result.|
#
# ### Reflection
# Discrepencies:
# - The only way I differed from the college board's score was by believing that this student deserved the test point in that category. Setting the requirements in relation to the parameters seemed like it may be worth a point, however there are actually minor details that don't.
#
# How my project can meet standards(How am I going to use these lessons?):
# - By clearly defining the characteristics and requirements that must be satisfied, I can apply what I learnt from this submission to my project. They must have specific requirements and demonstrate the importance of each stage. The objective and function are never truly achieved, and it doesn't demonstrate complete understanding if some of it doesn't match up with or relate to what the project was previously about.
#
# ### How will my project specifically achieve these categories?
# > Basic ideas and general topics about how will I show understanding of each section --> *just personal ideas and brainstorm
#
# |Category|Our CPT Project|
# |---|---|
# |Program Purpose and Function|The purpose of our program is save ourselves the time and have a good time in dubai. The function would be navigating a website that holds all our travel plans that will help us keep track fo expenses while also blogging and keeping good memories. There are many different functions included in our project|
# |Data Abstraction|We could try and use a list that holds different yelp comments and try to access them with a star rating for different foods and activities. The name could be sortyelpComments and this would be beneficial in showing ourselves, the users, what the best quality resturaunt/activity is worth it.|
# |Managing Complexity|This list would help manage complexity because it would be narrowed down into specific desires. For example, the low rated comments would be 1 star and the user could click to see 1 star reviews. Without this list we could not see the specific ratings.|
# |Procedural Abstraction|I will need to set accurate parameters in our project. It could be named rateStuff and the user will be able to add their own review on this section. We would also explain how this input value will work for the function.|
# |Algorithm Implementation|Our code will need to include sequencing, selection (if statement), and iteration (for loop). The user will input an integer for their star rating.|
# |Testing|Lastly, we would make sure to set specific conditions for our testing. The responses must also be relevant to the project and describe which conditions are being tested.|

# %% [markdown]
# # 5.1
#
# ### Class Discussion Topics and Notes:
#
# What do people think about drones?
# - They can be beneficial to
#
# ### Blog Post Reflection
#
# 1. Come up with three of your own Beneficial and corresponding Harmful Effects of Computing
# - c
#
# 2. Talk about dopamine issues above. Real? Parent conspiracy? Anything that is impacting your personal study and success in High School?
# - c
#
# # 5.2
#
# ### Class Discussion Topics and Notes:
#
# ### Blog Post Reflection
#
# 1. How does someone empower themself in a digital world?
# - c
#
# 2. How does someone that is empowered help someone that is not empowered? Describe something you could do at Del Norte HS.
# - c
#
# 3. Is paper or red tape blocking digital empowerment? Are there such barriers at Del Norte? Elsewhere?
# - c
#
# # Assignment Questions
#
# 1. Think of three beneficial effects of your projects based on 5.1 Unit
# - c
#
# 2. Think of a potential harmful effect of your project.
# - c
#
# 3. Answer with an opinion and learnings so far this year:  What are pros/cons on internet blockers at router and lack of admin password on lab machines at school?
# - c
#
# 4. What concerns do you have personally about the digital divide?  For yourself or for others.
# - c
